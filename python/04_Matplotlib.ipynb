# %% [markdown]
# <a href="https://colab.research.google.com/github/Hanjateacherson/SMHRD/blob/main/python/04_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt-get install ttf-mscorefonts-installer
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ttf-mscorefonts-installer is already the newest version (3.8ubuntu2).
# 0 upgraded, 0 newly installed, 0 to remove and 24 not upgraded.

# %%
# !sudo apt-get install fonts-nanum
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 24 not upgraded.

# %% [markdown]
# # Matplotlib

# %% [markdown]
# ### 데이터를 한 눈에 볼 수 있게 도표나 차트로 정리를 도와주는 라이브러리
# ### 시각화를 통해 데이터의 특징을 파악 가능
# ### 분석 결과를 상대방에 효과적으로 전달 가능

# %% [markdown]
# ### bar(count), scatter, line
#
# ### pie, histogram, boxplot

# %% [markdown]
# #### matplotlib 존재하는 sub 패키지

# %% [markdown]
# ![image.png](data:image/png;base64,...![image.png]())![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'NanumGothic'

# %% [markdown]
# # Line plot

# %%
#line plot을 그리기 위해서는 x축 y축이 필요
x = np.arange(1,6) # x = [1,2,3,4,5]
np.random.seed(3)
y = np.random.randint(1,10, size =5) #y = [?,?,?,?,?]

print(x)
print(y)
# Out:
# [1 2 3 4 5]
# [9 4 9 9 1]

# %%
# plt.plot(x축, y축)

plt.plot(x,y)
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# ...

# %%
# plt.plot(y축)
# -- x축은 자동으로 0~ y축의 개수 만큼 증가
plt.plot(y)
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print(x)
print(y)
# Out:
# [1 2 3 4 5]
# [9 4 9 9 1]

# %%
plt.plot(x,y, ls = ":")
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# ...

# %%
plt.plot(x,y, ls = ":",c = 'r', marker = 'D', mec = 'b', mfc = 'b')

#만약 그래프가 안나오면 plt.show() 사용해주기
# 쥬피터 노트북은 출력을 지원하는 개발환경이라서 사용 안해줘도 출력
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# ...

# %%
# 한 화면에 여러개의 그래프를 출력

#방법 : plt.subplot(row, col, index)


plt.subplot(2,2,1)
plt.plot(x,y, ls = '-', c = 'b', marker = "D", ms = 10, mec = 'c', mew = 4, mfc = 'y')

plt.subplot(2,2,2)
plt.plot(x,y, ls = '--', c = 'm', lw = 5)

plt.subplot(2,2,3)
plt.plot(x,y, ls = '-.')

plt.subplot(2,2,4)
plt.plot(x,y, ls = ':')
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# ...

# %%
# 여러 그래프를 한 창에 그려지게(그래프 겹치기)

one_x =np.arange(1,4) #[1,2,3]
one_y = np.array([1,2,3])
one_y2 = np.array([4,5,1])
one_y3 = np.array([3,6,2])

plt.plot(one_x, one_y)
plt.plot(one_x, one_y2)
plt.plot(one_x, one_y3)
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# ...

# %%
#plt.show()
plt.plot(one_x, one_y)
plt.show()

plt.plot(one_x, one_y2)
plt.plot(one_x, one_y3)
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # title

# %%
# title - plot.title('타이틀 적기')

print(x)
print(y)

plt.title('Test title')
plt.plot(x,y)
# Out:
# [1 2 3 4 5]
# [9 4 9 9 1]
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# ...

# %% [markdown]
# # grid()

# %%
# 격자눈금 함수
#plt.grid()

plt.plot(x,y)
plt.title('Test title')
plt.grid()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# ...

# %% [markdown]
# # legend()

# %%
test_x = np.arange(1,6)
np.random.seed(5)
test_y = np.random.randint(1,10,size=5)

test_x1 = np.arange(1,6)
np.random.seed(10)
test_y1 = np.random.randint(1,10,size=5)

print(test_x)
print(test_y)
print(test_x1)
print(test_y1)
# Out:
# [1 2 3 4 5]
# [4 7 7 1 9]
# [1 2 3 4 5]
# [5 1 2 1 2]

# %%
# legend() 사용방법
# plt.lengend()
# 단, plt.plot을 그릴 때 해당 plot의 label 값을 지정해주어야 합니다!
# ↪️ plt.plot(x,y, label = '라벨값 지정')


plt.plot(test_x, test_y, label = 'y')
plt.plot(test_x1, test_y1, label= 'y1')
plt.legend(loc = 'upper right')
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# ...

# %% [markdown]
# # xlabel(), ylabel()

# %%
plt.plot(test_x,test_y, label = 'y')
plt.plot(test_x1,test_y1, label = 'y1')
plt.legend(loc = 'upper right')

plt.xlabel('x축')
plt.xlabel('y축')
# Out:
# Text(0.5, 0, 'y축')
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# ...

# %% [markdown]
# # xlim(), ylim()

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'

# %%
# plt.xlable('이름')
# plt.ylable('이름')


plt.plot(test_x, test_y, label = 'y')
plt.plot(test_x1, test_y1, label = 'y1')
plt.legend(loc = 'upper right')

plt.xlabel('x축')
plt.ylabel('y축')
# Out:
# Text(0, 0.5, 'y축')
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# ...

# %%
# xlim, ylim

plt.plot(test_x,test_y, label = 'y')
plt.plot(test_x1,test_y1, label = 'y1')
plt.legend(loc = 'upper right')

plt.xlabel('x축')
plt.xlabel('y축')

# x,y이 문자열인 경우 문자로 작성
plt.xlim(0,10)
plt.ylim(0,20)
# Out:
# (0.0, 20.0)
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# ...

# %% [markdown]
# # xticks, yticks

# %%
#사용법 xticks, yticks(list, 배열)


plt.plot(test_x, test_y, label = 'y')
plt.plot(test_x1, test_y1, label = 'y1')
plt.legend(loc = 'upper right')

plt.xlabel('x축')
plt.ylabel('y축')

plt.xticks(range(1,5)) # 1,2,3,4,5
plt.yticks(range(1,11,2)) # 1,3,5,7,9
# Out:
# ([<matplotlib.axis.YTick at 0x7de88dd432b0>,
# ...
#  [Text(0, 1, '1'),
#   Text(0, 3, '3'),
#   Text(0, 5, '5'),
#   Text(0, 7, '7'),
#   Text(0, 9, '9')])
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# ...

# %% [markdown]
# # 실습) 장래 인구 변동 데이터

# %%
# 컬럼 하나를 인덱스
fu_pop =pd.read_csv('/content/drive/MyDrive/data/장래_인구변동_KOSIS.csv', encoding='euc-kr', index_col = '인구변동요인별')
fu_pop
# Out:
#            2020   2030   2040   2050   2060   2070
# 인구변동요인별
# 인구(천명)    51836  51199  50193  47359  42617  37656
# 출생아수(천명)    275    305    286    236    181    196
# 사망자수(천명)    308    408    527    680    741    702

# %%
#.columns - 해당 df 컬럼들을 가지고 올수 있습니다
fu_pop.columns
fu_pop_x = list(fu_pop.columns)
print(fu_pop_x)
# Out:
# ['2020', '2030', '2040', '2050', '2060', '2070']

# %% [markdown]
# # 연도별 출생아 수

# %%
#데이터 접근
fu_pop_y = fu_pop.iloc[1]
fu_pop_y
# Out:
# 2020    275
# 2030    305
# 2040    286
# 2050    236
# 2060    181
# 2070    196
# Name: 출생아수(천명), dtype: int64

# %%
plt.plot(fu_pop_x, fu_pop_y)
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# ...

# %% [markdown]
# # 실습문제
#  - 출생아수, 사망자수 그래프

# %%
print(fu_pop_x)
print(fu_pop_y)

fu_pop_y2 = fu_pop.iloc[2]
fu_pop_y2
# Out:
# ['2020', '2030', '2040', '2050', '2060', '2070']
# 2020    275
# 2030    305
# 2040    286
# 2050    236
# 2060    181
# 2070    196
# Name: 출생아수(천명), dtype: int64
# 2020    308
# 2030    408
# 2040    527
# 2050    680
# 2060    741
# 2070    702
# Name: 사망자수(천명), dtype: int64

# %%
plt.plot(fu_pop_x, fu_pop_y, marker = '*', ms = 10, label = '출생아수(천명)')
plt.plot(fu_pop_x , fu_pop_y2 , marker='o',label = '사망자수(천명)')
plt.title('국가통계 요인별 장래 인구 동향')
plt.xlabel('연도')
plt.ylabel('사람수')
plt.legend()
plt.grid()

plt.yticks(range(150, 751 , 50))
# Out:
# ([<matplotlib.axis.YTick at 0x7de88dc57e20>,
# ...
#  [Text(0, 150, '150'),
#   Text(0, 200, '200'),
#   Text(0, 250, '250'),
#   Text(0, 300, '300'),
#   Text(0, 350, '350'),
#   Text(0, 400, '400'),
#   Text(0, 450, '450'),
#   Text(0, 500, '500'),
#   Text(0, 550, '550'),
#   Text(0, 600, '600'),
#   Text(0, 650, '650'),
#   Text(0, 700, '700'),
#   Text(0, 750, '750')])
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# ...

# %% [markdown]
# # 그래프 이미지 화

# %%
plt.plot(fu_pop_x, fu_pop_y, marker = '*', ms = 10, label = '출생아수(천명)')
plt.plot(fu_pop_x , fu_pop_y2 , marker='o',label = '사망자수(천명)')
plt.title('국가통계 요인별 장래 인구 동향')
plt.xlabel('연도')
plt.ylabel('사람수')
plt.legend()
plt.grid()

plt.yticks(range(150, 751 , 50))

#plt.savefig('경로/파일명.png', dpi = , bbox_inches )
#dpi = dots per inch  해상도 설정
#bbox_inches = 저장할 부분의 공간을 지정 = tight 그림의 빈 공간을 최소화

plt.savefig('./test1.png', dpi = 600, bbox_inches = 'tight')
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# ...

# %%
temp_data = pd.read_csv('/content/drive/MyDrive/data/온도데이터(1971-2023).csv', encoding='euc-kr',skiprows=range(0,7))

# %%
temp_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19155 entries, 0 to 19154
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   날짜       19155 non-null  object
#  1   지점       19155 non-null  int64
#  2   평균기온(℃)  19155 non-null  float64
#  3   최저기온(℃)  19154 non-null  float64
#  4   최고기온(℃)  19154 non-null  float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 748.4+ KB

# %%
temp_data[temp_data.iloc[:,4].isna()]
# Out:
#                 날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 1019  \t1973-10-16  156     11.9      NaN      NaN

# %% [markdown]
# # 본인 생일의 연도별 최고, 최저기온

# %%
temp_data.iloc[1018,:]
# Out:
# 날짜         \t1973-10-15
# 지점                  156
# 평균기온(℃)            11.6
# 최저기온(℃)             3.8
# 최고기온(℃)            20.0
# Name: 1018, dtype: object

# %%
#평균 온도 - lineplot으로

temp_data['평균기온(℃)']
# Out:
# 0         2.0
# 1        -0.2
# 2        -0.7
# 3        -6.4
# 4        -8.4
#          ...
# 19150    21.7
# 19151    22.5
# 19152    24.2
# 19153    24.1
# 19154    24.5
# Name: 평균기온(℃), Length: 19155, dtype: float64

# %%
plt.plot(temp_data['평균기온(℃)'])
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# ...

# %% [markdown]
# # 본인 생일의 평균 온도

# %%
temp_data.head()
# Out:
#              날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 0  \t1971-01-01  156      2.0     -0.6      6.3
# 1  \t1971-01-02  156     -0.2     -4.0      5.0
# 2  \t1971-01-03  156     -0.7     -5.2      5.3
# 3  \t1971-01-04  156     -6.4     -9.3     -0.9
# 4  \t1971-01-05  156     -8.4    -13.9     -4.7

# %%
#파생변수 새로운 컬럼 월-일
temp_data['날짜'][-5:]
# Out:
# 19150    \t2023-06-07
# 19151    \t2023-06-08
# 19152    \t2023-06-09
# 19153    \t2023-06-10
# 19154    \t2023-06-11
# Name: 날짜, dtype: object

# %%
temp_data['날짜'].str[-5:]
# Out:
# 0        01-01
# 1        01-02
# 2        01-03
# 3        01-04
# 4        01-05
#          ...
# 19150    06-07
# 19151    06-08
# 19152    06-09
# 19153    06-10
# 19154    06-11
# Name: 날짜, Length: 19155, dtype: object

# %%
temp_data['월일'] = temp_data['날짜'].str[-5:]
temp_data
# Out:
#                  날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)     월일
# 0      \t1971-01-01  156      2.0     -0.6      6.3  01-01
# 1      \t1971-01-02  156     -0.2     -4.0      5.0  01-02
# 2      \t1971-01-03  156     -0.7     -5.2      5.3  01-03
# 3      \t1971-01-04  156     -6.4     -9.3     -0.9  01-04
# 4      \t1971-01-05  156     -8.4    -13.9     -4.7  01-05
# ...             ...  ...      ...      ...      ...    ...
# 19150  \t2023-06-07  156     21.7     16.4     28.6  06-07
# 19151  \t2023-06-08  156     22.5     18.1     29.0  06-08
# 19152  \t2023-06-09  156     24.2     19.2     30.5  06-09
# 19153  \t2023-06-10  156     24.1     20.8     30.9  06-10
# 19154  \t2023-06-11  156     24.5     21.4     30.7  06-11
#
# [19155 rows x 6 columns]

# %%
#1971/1 ~
# 본인 생일만 검색
birth_data = temp_data.query("월일 == '04-26'")
birth_data
# Out:
#                  날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)     월일
# 115    \t1971-04-26  156     16.1      7.4     25.0  04-26
# 481    \t1972-04-26  156     14.0      9.4     19.9  04-26
# 846    \t1973-04-26  156     17.0     10.2     20.9  04-26
# 1211   \t1974-04-26  156      9.3      5.9     13.6  04-26
# 1576   \t1975-04-26  156     17.2     15.1     18.5  04-26
# 1942   \t1976-04-26  156     16.1     11.0     22.4  04-26
# 2307   \t1977-04-26  156     14.2      7.5     22.7  04-26
# 2672   \t1978-04-26  156     14.5      6.1     23.5  04-26
# 3037   \t1979-04-26  156     15.4      8.6     22.3  04-26
# 3403   \t1980-04-26  156     14.0      3.8     23.0  04-26
# 3768   \t1981-04-26  156     14.3      5.5     23.4  04-26
# 4133   \t1982-04-26  156     18.1     15.3     22.0  04-26
# 4498   \t1983-04-26  156     20.7     16.8     23.9  04-26
# 4864   \t1984-04-26  156     16.8     13.5     21.5  04-26
# 5229   \t1985-04-26  156     14.4      7.6     18.0  04-26
# ...

# %%
plt.title('내 생일 평균 온도')
plt.plot(range(1971,2024), birth_data['평균기온(℃)'])
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 45236 (\N{HANGUL SYLLABLE NAE}) missing from current font.
#   func(*args, **kwargs)
# ...

# %% [markdown]
# # 실습) 내 생일 최저, 최고기온 시각화

# %%
plt.plot(range(1971,2024), birth_data['최저기온(℃)'], label = "최저기온")
plt.plot(range(1971,2024), birth_data['최고기온(℃)'], label = "최고기온")
plt.legend()
plt.title('birth_high_low_tdata')
# Out:
# Text(0.5, 1.0, 'birth_high_low_tdata')
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# ...

# %% [markdown]
# # ======================================

# %% [markdown]
# #히스토그램
# - 데이터의 빈도를막대그래프 형식으로 표

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#주사위를 100번 던져서 나오는 수들의 분포를 히스토그램으로 그려보기
np.random.seed(3)
a = np.random.randint(1,7, size = 100)
a
# Out:
# array([3, 1, 2, 4, 1, 1, 1, 6, 6, 4, 3, 4, 2, 2, 3, 6, 1, 5, 5, 6, 1, 3,
#        2, 3, 3, 3, 5, 2, 4, 3, 6, 1, 2, 6, 3, 1, 4, 1, 4, 2, 4, 1, 6, 5,
#        2, 6, 5, 5, 1, 1, 2, 3, 5, 6, 1, 1, 6, 6, 2, 2, 2, 6, 6, 3, 4, 5,
#        5, 4, 4, 1, 1, 1, 1, 3, 3, 4, 1, 6, 6, 1, 6, 2, 5, 2, 5, 3, 3, 5,
#        5, 3, 1, 5, 1, 4, 3, 1, 5, 4, 2, 6])

# %%
np.unique(a, return_counts=True)
# Out:
# (array([1, 2, 3, 4, 5, 6]), array([23, 15, 17, 13, 15, 17]))

# %% [markdown]
# # plt.hist()

# %%
plt.hist(a, bins = 6)# bin 매개 변수 - 해당 히스토그램을 몇개로 나눌 것인지
# Out:
# (array([23., 15., 17., 13., 15., 17.]),
#  array([1.        , 1.83333333, 2.66666667, 3.5       , 4.33333333,
#         5.16666667, 6.        ]),
#  <BarContainer object of 6 artists>)
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# ...

# %%
temp_data
# Out:
#                  날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)     월일
# 0      \t1971-01-01  156      2.0     -0.6      6.3  01-01
# 1      \t1971-01-02  156     -0.2     -4.0      5.0  01-02
# 2      \t1971-01-03  156     -0.7     -5.2      5.3  01-03
# 3      \t1971-01-04  156     -6.4     -9.3     -0.9  01-04
# 4      \t1971-01-05  156     -8.4    -13.9     -4.7  01-05
# ...             ...  ...      ...      ...      ...    ...
# 19150  \t2023-06-07  156     21.7     16.4     28.6  06-07
# 19151  \t2023-06-08  156     22.5     18.1     29.0  06-08
# 19152  \t2023-06-09  156     24.2     19.2     30.5  06-09
# 19153  \t2023-06-10  156     24.1     20.8     30.9  06-10
# 19154  \t2023-06-11  156     24.5     21.4     30.7  06-11
#
# [19155 rows x 6 columns]

# %%
# 월의 최고 기온을 히스토그램

#파생변수
temp_data['월'] = temp_data['월일'].str[:2]
temp_data
# Out:
#                  날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)     월일   월
# 0      \t1971-01-01  156      2.0     -0.6      6.3  01-01  01
# 1      \t1971-01-02  156     -0.2     -4.0      5.0  01-02  01
# 2      \t1971-01-03  156     -0.7     -5.2      5.3  01-03  01
# 3      \t1971-01-04  156     -6.4     -9.3     -0.9  01-04  01
# 4      \t1971-01-05  156     -8.4    -13.9     -4.7  01-05  01
# ...             ...  ...      ...      ...      ...    ...  ..
# 19150  \t2023-06-07  156     21.7     16.4     28.6  06-07  06
# 19151  \t2023-06-08  156     22.5     18.1     29.0  06-08  06
# 19152  \t2023-06-09  156     24.2     19.2     30.5  06-09  06
# 19153  \t2023-06-10  156     24.1     20.8     30.9  06-10  06
# 19154  \t2023-06-11  156     24.5     21.4     30.7  06-11  06
#
# [19155 rows x 7 columns]

# %%
# 12월의 최고 기온
month_temp = temp_data.query('월 == "12"')
month_temp
# Out:
#                  날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)     월일   월
# 334    \t1971-12-01  156      5.5      1.7      9.9  12-01  12
# 335    \t1971-12-02  156      9.1      4.6     13.2  12-02  12
# 336    \t1971-12-03  156      6.9      1.8     10.2  12-03  12
# 337    \t1971-12-04  156      5.8     -1.8     12.8  12-04  12
# 338    \t1971-12-05  156      7.0      1.4     13.0  12-05  12
# ...             ...  ...      ...      ...      ...    ...  ..
# 18988  \t2022-12-27  156      0.3     -4.2      5.7  12-27  12
# 18989  \t2022-12-28  156     -0.2     -3.4      5.2  12-28  12
# 18990  \t2022-12-29  156      0.7     -3.7      5.1  12-29  12
# 18991  \t2022-12-30  156      1.0     -2.2      5.4  12-30  12
# 18992  \t2022-12-31  156      1.4     -1.5      6.0  12-31  12
#
# [1612 rows x 7 columns]

# %%
plt.hist(month_temp['최고기온(℃)'], bins = 100 , color = 'r', alpha = 0.5) # alpha 투명도 : 소수점
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# ...

# %%
plt.hist(month_temp['최고기온(℃)'], bins = 100 , color = 'r', alpha = 0.5, label = 'r-최고기온') # alpha 투명도 : 소수점
plt.hist(month_temp['최저기온(℃)'], bins = 100 , color = 'b', alpha = 0.5, label = 'b-최저기온') # alpha 투명도 : 소수점
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# ...

# %% [markdown]
# # Boxplot

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 1D 데이터 준비하여 박스 플롯 그려보기
np.random.seed(1)
tmp_data = np.random.randint(10,size = 10)
# print(tmp_data)
# tmp_data= np.append(tmp_data, 20)
# print(tmp_data)
plt.boxplot(tmp_data, labels=['데이터명'])
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45936 (\N{HANGUL SYLLABLE DE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 53552 (\N{HANGUL SYLLABLE TEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47749 (\N{HANGUL SYLLABLE MYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
temp_data
# Out:
#                  날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)     월일   월
# 0      \t1971-01-01  156      2.0     -0.6      6.3  01-01  01
# 1      \t1971-01-02  156     -0.2     -4.0      5.0  01-02  01
# 2      \t1971-01-03  156     -0.7     -5.2      5.3  01-03  01
# 3      \t1971-01-04  156     -6.4     -9.3     -0.9  01-04  01
# 4      \t1971-01-05  156     -8.4    -13.9     -4.7  01-05  01
# ...             ...  ...      ...      ...      ...    ...  ..
# 19150  \t2023-06-07  156     21.7     16.4     28.6  06-07  06
# 19151  \t2023-06-08  156     22.5     18.1     29.0  06-08  06
# 19152  \t2023-06-09  156     24.2     19.2     30.5  06-09  06
# 19153  \t2023-06-10  156     24.1     20.8     30.9  06-10  06
# 19154  \t2023-06-11  156     24.5     21.4     30.7  06-11  06
#
# [19155 rows x 7 columns]

# %%
temp_month = temp_data.query('월 == "01"')
temp_month
# Out:
#                  날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)     월일   월
# 0      \t1971-01-01  156      2.0     -0.6      6.3  01-01  01
# 1      \t1971-01-02  156     -0.2     -4.0      5.0  01-02  01
# 2      \t1971-01-03  156     -0.7     -5.2      5.3  01-03  01
# 3      \t1971-01-04  156     -6.4     -9.3     -0.9  01-04  01
# 4      \t1971-01-05  156     -8.4    -13.9     -4.7  01-05  01
# ...             ...  ...      ...      ...      ...    ...  ..
# 19019  \t2023-01-27  156     -2.8     -4.5     -0.3  01-27  01
# 19020  \t2023-01-28  156     -2.8     -7.7      1.9  01-28  01
# 19021  \t2023-01-29  156      1.3     -3.5      6.2  01-29  01
# 19022  \t2023-01-30  156      1.8     -1.3      6.3  01-30  01
# 19023  \t2023-01-31  156      3.7     -3.7     11.5  01-31  01
#
# [1643 rows x 7 columns]

# %% [markdown]
# # 1월의 평균 기온

# %%
plt.boxplot(temp_month['평균기온(℃)'])
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# ...

# %%
plt.boxplot(temp_month['평균기온(℃)'], labels=['평균기온'])
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44512 (\N{HANGUL SYLLABLE GYUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50728 (\N{HANGUL SYLLABLE ON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
# 2D 데이터 준비하여 박스 플롯 그려보기
np.random.seed(6)
tmp_data2 = np.random.randint(1,50,size=(10,2))
print(tmp_data2)
plt.boxplot(tmp_data2, labels = ['1열','2열'])
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50676 (\N{HANGUL SYLLABLE YEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# ...

# %%
temp_month
# Out:
#                  날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)     월일   월
# 0      \t1971-01-01  156      2.0     -0.6      6.3  01-01  01
# 1      \t1971-01-02  156     -0.2     -4.0      5.0  01-02  01
# 2      \t1971-01-03  156     -0.7     -5.2      5.3  01-03  01
# 3      \t1971-01-04  156     -6.4     -9.3     -0.9  01-04  01
# 4      \t1971-01-05  156     -8.4    -13.9     -4.7  01-05  01
# ...             ...  ...      ...      ...      ...    ...  ..
# 19019  \t2023-01-27  156     -2.8     -4.5     -0.3  01-27  01
# 19020  \t2023-01-28  156     -2.8     -7.7      1.9  01-28  01
# 19021  \t2023-01-29  156      1.3     -3.5      6.2  01-29  01
# 19022  \t2023-01-30  156      1.8     -1.3      6.3  01-30  01
# 19023  \t2023-01-31  156      3.7     -3.7     11.5  01-31  01
#
# [1643 rows x 7 columns]

# %% [markdown]
# # 최고기온, 최저기온

# %%
plt.rcParams['axes.unicode_minus'] = False
plt.boxplot(temp_month[['최저기온(℃)', '최고기온(℃)']], labels=['최저기온', '최고기온'])
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52572 (\N{HANGUL SYLLABLE COE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51200 (\N{HANGUL SYLLABLE JEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50728 (\N{HANGUL SYLLABLE ON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %% [markdown]
# # barplot

# %%
np.random.seed(6)
bar_x = np.arange(1,4)
bar_y = np.random.randint(50,100, size = 3)

#plt.bar(x,y)
plt.bar(bar_x, bar_y)
# Out:
# <BarContainer object of 3 artists>
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# ...

# %%
# barplot 색깔
plt.bar(bar_x, bar_y, color = {'red','blue','green'})
# Out:
# <BarContainer object of 3 artists>
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# ...

# %% [markdown]
# # 그래프 색상 함수

# %%
# https://matplotlib.org/stable/gallery/color/named_colors.html#base-colors  doc제공 코드
import math
from matplotlib.patches import Rectangle
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors


def plot_colortable(colors, *, ncols=4, sort_colors=True):

    cell_width = 212
    cell_height = 22
    swatch_width = 48
    margin = 12

    # Sort colors by hue, saturation, value and name.
    if sort_colors is True:
        names = sorted(
            colors, key=lambda c: tuple(mcolors.rgb_to_hsv(mcolors.to_rgb(c))))
    else:
        names = list(colors)

    n = len(names)
    nrows = math.ceil(n / ncols)

    width = cell_width * 4 + 2 * margin
    height = cell_height * nrows + 2 * margin
    dpi = 72

    fig, ax = plt.subplots(figsize=(width / dpi, height / dpi), dpi=dpi)
    fig.subplots_adjust(margin/width, margin/height,
                        (width-margin)/width, (height-margin)/height)
    ax.set_xlim(0, cell_width * 4)
    ax.set_ylim(cell_height * (nrows-0.5), -cell_height/2.)
    ax.yaxis.set_visible(False)
    ax.xaxis.set_visible(False)
    ax.set_axis_off()

    for i, name in enumerate(names):
        row = i % nrows
        col = i // nrows
        y = row * cell_height

        swatch_start_x = cell_width * col
        text_pos_x = cell_width * col + swatch_width + 7

        ax.text(text_pos_x, y, name, fontsize=14,
                horizontalalignment='left',
                verticalalignment='center')

        ax.add_patch(
            Rectangle(xy=(swatch_start_x, y-9), width=swatch_width,
                      height=18, facecolor=colors[name], edgecolor='0.7')
        )

    return fig

# %%
plot_colortable(mcolors.CSS4_COLORS)
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# ...

# %% [markdown]
# # barplot 안에 글씨 넣어보기

# %%
print(bar_x)
print(bar_y)
# Out:
# [1 2 3]
# [60 59 85]

# %%
bar_x[0]
# Out:
# 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# x, y, s
#bar 하나에 작성이 되는 것 - 요소 하나하나 작성
#ha = horizental alignment
#va = vertical alignment
plt.bar(bar_x, bar_y, color = ['red','blue','green'])

# plt.text(bar_x[0],bar_y[0], bar_y[0], fontdict={'color' : 'black', 'size' : 14}, ha = 'center', va = 'bottom')
# plt.text(bar_x[1],bar_y[1], bar_y[1], fontdict={'color' : 'black', 'size' : 14}, ha = 'center', va = 'bottom')

for i in range(len(bar_x)): #range(3) 0~2
    plt.text(bar_x[i],bar_y[i], bar_y[i], fontdict={'color' : 'black', 'size' : 14}, ha = 'center', va = 'bottom')


plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# ...

# %%
sidoGender = pd.read_csv('/content/drive/MyDrive/data/시도_성별_경제활동인구_총괄_KOSIS_2022.csv',encoding='euc-kr')
sidoGender
# Out:
#    행정구역(시도)  성별  15세이상인구 (천명)  경제활동인구 (천명)  취업자 (천명)  실업자 (천명)  비경제활동인구 (천명)  \
# 0     서울특별시  남자          4007         2849      2760        89          1158
# 1     서울특별시  여자          4440         2418      2347        72          2022
# 2     부산광역시  남자          1406          973       946        27           433
# 3     부산광역시  여자          1528          768       745        23           760
# 4     대구광역시  남자          1001          708       691        17           294
# 5     대구광역시  여자          1071          556       543        13           515
# 6     인천광역시  남자          1279          955       928        27           324
# 7     인천광역시  여자          1309          732       717        15           577
# 8     광주광역시  남자           623          434       423        10           190
# 9     광주광역시  여자           656          346       339         8           309
# 10    대전광역시  남자           635          466       461         5           169
# ...

# %%
sidoGender.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   행정구역(시도)      34 non-null     object
#  1   성별            34 non-null     object
#  2   15세이상인구 (천명)  34 non-null     int64
#  3   경제활동인구 (천명)   34 non-null     int64
#  4   취업자 (천명)      34 non-null     int64
#  5   실업자 (천명)      34 non-null     int64
#  6   비경제활동인구 (천명)  34 non-null     int64
#  7   경제활동참가율(％)    34 non-null     float64
#  8   고용률(%)        24 non-null     float64
#  9   실업률(%)        28 non-null     float64
# dtypes: float64(3), int64(5), object(2)
# memory usage: 2.8+ KB

# %%
#고용률 전처리

#고용률 = 취업자/ 15세이상 인구

# sidoGender.query('고용률(%).isna()')
# sidoGender[sidoGender['고용률(%)'].notna()]
sidoGender[sidoGender['고용률(%)'].isna()]
# Out:
#    행정구역(시도)  성별  15세이상인구 (천명)  경제활동인구 (천명)  취업자 (천명)  실업자 (천명)  비경제활동인구 (천명)  \
# 1     서울특별시  여자          4440         2418      2347        72          2022
# 5     대구광역시  여자          1071          556       543        13           515
# 6     인천광역시  남자          1279          955       928        27           324
# 7     인천광역시  여자          1309          732       717        15           577
# 8     광주광역시  남자           623          434       423        10           190
# 9     광주광역시  여자           656          346       339         8           309
# 10    대전광역시  남자           635          466       461         5           169
# 11    대전광역시  여자           653          353       346         7           300
# 17      경기도  여자          5981         3283      3199        84          2697
# 27     전라남도  여자           763          460       454         6           302
#
#     경제활동참가율(％)  고용률(%)  실업률(%)
# 1         54.5     NaN     3.0
# 5         51.9     NaN     NaN
# ...

# %%
temp_goyong = sidoGender['취업자 (천명)']/sidoGender['15세이상인구 (천명)']
#round() 실수의 자릿수(범위) 지정
#round(data, 숫자)
temp_goyong = round(temp_goyong, 3) * 100
temp_goyong
# Out:
# 0     68.9
# 1     52.9
# 2     67.3
# 3     48.8
# 4     69.0
# 5     50.7
# 6     72.6
# 7     54.8
# 8     67.9
# 9     51.7
# 10    72.6
# 11    53.0
# 12    71.4
# 13    48.1
# 14    76.3
# 15    52.5
# 16    75.0
# 17    53.5
# 18    69.7
# 19    58.2
# 20    75.2
# 21    56.4
# 22    75.9
# 23    57.8
# 24    70.5
# 25    56.5
# 26    74.9
# 27    59.5
# 28    73.2
# 29    55.0
# 30    70.7
# 31    52.1
# 32    77.5
# 33    67.0
# dtype: float64

# %%
sidoGender['고용률(%)'] = temp_goyong
sidoGender[sidoGender['고용률(%)'].isna()]
# Out:
# Empty DataFrame
# Columns: [행정구역(시도), 성별, 15세이상인구 (천명), 경제활동인구 (천명), 취업자 (천명), 실업자 (천명), 비경제활동인구 (천명), 경제활동참가율(％), 고용률(%), 실업률(%)]
# Index: []

# %%
# 실업률 전처리
# 실업률 = 실업자/경제활동인구
sidoGender
temp_unemp =  sidoGender['실업자 (천명)']/sidoGender['경제활동인구 (천명)']
temp_unemp = round(temp_unemp,3) *100
sidoGender['실업률(%)'] = temp_unemp
sidoGender[sidoGender['실업률(%)'].isna()]
# Out:
# Empty DataFrame
# Columns: [행정구역(시도), 성별, 15세이상인구 (천명), 경제활동인구 (천명), 취업자 (천명), 실업자 (천명), 비경제활동인구 (천명), 경제활동참가율(％), 고용률(%), 실업률(%)]
# Index: []

# %%
sidoGender.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   행정구역(시도)      34 non-null     object
#  1   성별            34 non-null     object
#  2   15세이상인구 (천명)  34 non-null     int64
#  3   경제활동인구 (천명)   34 non-null     int64
#  4   취업자 (천명)      34 non-null     int64
#  5   실업자 (천명)      34 non-null     int64
#  6   비경제활동인구 (천명)  34 non-null     int64
#  7   경제활동참가율(％)    34 non-null     float64
#  8   고용률(%)        34 non-null     float64
#  9   실업률(%)        34 non-null     float64
# dtypes: float64(3), int64(5), object(2)
# memory usage: 2.8+ KB

# %%
sidoGender
# Out:
#    행정구역(시도)  성별  15세이상인구 (천명)  경제활동인구 (천명)  취업자 (천명)  실업자 (천명)  비경제활동인구 (천명)  \
# 0     서울특별시  남자          4007         2849      2760        89          1158
# 1     서울특별시  여자          4440         2418      2347        72          2022
# 2     부산광역시  남자          1406          973       946        27           433
# 3     부산광역시  여자          1528          768       745        23           760
# 4     대구광역시  남자          1001          708       691        17           294
# 5     대구광역시  여자          1071          556       543        13           515
# 6     인천광역시  남자          1279          955       928        27           324
# 7     인천광역시  여자          1309          732       717        15           577
# 8     광주광역시  남자           623          434       423        10           190
# 9     광주광역시  여자           656          346       339         8           309
# 10    대전광역시  남자           635          466       461         5           169
# ...

# %%
#시 도별 고용률 평균 시각화
goyong_rate = sidoGender[['행정구역(시도)', '고용률(%)']].groupby('행정구역(시도)', as_index=False).mean(True)
goyong_rate.sort_values(by ='고용률(%)' ,ascending=False ).head(5)
# Out:
#    행정구역(시도)  고용률(%)
# 14  제주특별자치도   72.25
# 12     전라남도   67.20
# 15     충청남도   66.85
# 16     충청북도   65.80
# 9   세종특별자치시   64.40

# %%
# 그래프의 사이즈
#plt.figure(figsize= (가로, 세로)) #단위는 인치
plt.figure(figsize= (10,4))

plt.bar(goyong_rate['행정구역(시도)'], goyong_rate['고용률(%)'])
plt.title('시도별 고용률 평균')
plt.xlabel('행정구용(시도)')
plt.ylabel('고용률(%)')
#xticks 기울기
#xticks(rotation = 기울기 각도)
plt.xticks(rotation = 45)
plt.ylim(50,80)
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44256 (\N{HANGUL SYLLABLE GO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
plt.barh(goyong_rate['행정구역(시도)'], goyong_rate['고용률(%)'])
plt.xlim(50,80)
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# ...

# %%
#seaborn으로 그리기 - 고용률
plt.figure(figsize=(10,4))
sns.barplot(data = goyong_rate, x =goyong_rate['행정구역(시도)'], y =  goyong_rate['고용률(%)'] )
plt.xticks(rotation = 45)
plt.grid()
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50896 (\N{HANGUL SYLLABLE WEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from current font.
# ...

# %% [markdown]
# # 실습) 시도별 남자의 실업률 막대그래프

# %% [markdown]
#  ## + 시도별 여자의 실업률 막대그래프

# %%
man = sidoGender.query('성별 == "남자"')
man_unemp = man[['행정구역(시도)', '실업률(%)']]
man_unemp
# Out:
#    행정구역(시도)  실업률(%)
# 0     서울특별시     3.1
# 2     부산광역시     2.8
# 4     대구광역시     2.4
# 6     인천광역시     2.8
# 8     광주광역시     2.3
# 10    대전광역시     1.1
# 12    울산광역시     3.1
# 14  세종특별자치시     1.7
# 16      경기도     2.2
# 18      강원도     2.4
# 20     충청북도     2.2
# 22     충청남도     1.9
# 24     전라북도     1.6
# 26     전라남도     1.4
# 28     경상북도     2.4
# 30     경상남도     2.6
# 32  제주특별자치도     2.2

# %%
plt.figure(figsize=(15,8))
sns.barplot(data = man_unemp, x = man_unemp['행정구역(시도)'], y= man_unemp['실업률(%)'])
plt.xticks(rotation = 45)
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49436 (\N{HANGUL SYLLABLE SEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50872 (\N{HANGUL SYLLABLE UL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 53945 (\N{HANGUL SYLLABLE TEUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %% [markdown]
# # Scatter

# %%
np.random.seed(2)
x = np.arange(1,4)
y = np.random.rand(3)
print(x,y)

plt.scatter(x, y)
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# ...

# %%
np.random.seed(2)
x = np.arange(1,4)
y = np.random.rand(3)
print(x,y)

#매개변수 추가하기
# s (scale) =[요소의 개수 만큼 크기 숫자를 작성]
plt.scatter(x, y,  s= [100,200,300])
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# ...

# %%
np.random.seed(2)
x = np.arange(1,4)
y = np.random.rand(3)
print(x,y)

#매개변수 추가하기
# c (color) =[요소의 개수 만큼 크기 색상을 작성]
plt.scatter(x, y,  s= [100,200,300], c = ['r','c','y'])
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# [1 2 3] [0.4359949  0.02592623 0.54966248]
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# ...

# %%
np.random.seed(2)
x = np.arange(1,4)
y = np.random.rand(3)
print(x,y)

#매개변수 추가하기
# cmap https://matplotlib.org/stable/users/explain/colors/colormaps.html 사이트에 존재하는
# 색상 팔레트 사용
# cmap 사용시 c = range(개수) 로 범위를 지정

plt.scatter(x, y,  s= [100,200,300], c = range(3), cmap = 'cool')

#
plt.colorbar()
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# ...

# %% [markdown]
# # Pie 차트

# %%
# 사용법 : plt.pie(size, label = labels, autopct = 실수형0),

# size : 파이차트의 크기를 담당하는 데이터
# labels : 각 부분의 라벨
# autopct : 자동으로 백분율을 계산 %.1f%% ➡️ 소수점 첫째자리까지 출력

sizes = [30,40,20,10]
labels = ['A','B','C','D']

plt.pie(sizes, labels = labels,autopct='%.1f%%')
plt.legend()
plt.title('test pie chart')
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# ...

# %%
# Pie 차트의 colors
sizes = [30,40,20,10]
labels = ['A','B','C','D']
colors = sns.color_palette("pastel")

# explode = [데이터의 개수에 맞게 작성]
# 🌐(폭발하다, 터뜨리다)
# 0이 기준 0.1만큼(10%) 원형 차트 떨어짐
plt.pie(sizes, labels = labels,autopct='%.1f%%', colors = colors,
        explode = [0,0.1,0,0])
plt.legend()
plt.title('test pie chart')
plt.show()
# autopct : 부채 꼴 안에 표시될 숫자 형식 지정
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# ...

# %% [markdown]
# # 시도별 실업자 비율이 가장 높은곳
# - 시도별로 묶기
# - 결측치 여부 확인 후 결측치 채워주기
# - 실업자(천명) 다 더하기

# %%
sido_sum = sidoGender.groupby('행정구역(시도)').sum()
sido_sum
# Out:
# <ipython-input-86-bc49153944e2>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sido_sum = sidoGender.groupby('행정구역(시도)').sum()
#           15세이상인구 (천명)  경제활동인구 (천명)  취업자 (천명)  실업자 (천명)  비경제활동인구 (천명)  \
# 행정구역(시도)
# 강원도               1326          868       847        21           458
# 경기도              11925         7843      7658       185          4081
# 경상남도              2848         1796      1749        47          1052
# 경상북도              2327         1527      1492        35           799
# 광주광역시             1279          780       762        18           499
# 대구광역시             2072         1264      1234        30           809
# 대전광역시             1288          819       807        12           469
# 부산광역시             2934         1741      1691        50          1193
# ...

# %%
unemp_sum = sido_sum["실업자 (천명)"]
unemp_sum
# Out:
# 행정구역(시도)
# 강원도         21
# 경기도        185
# 경상남도        47
# 경상북도        35
# 광주광역시       18
# 대구광역시       30
# 대전광역시       12
# 부산광역시       50
# 서울특별시      161
# 세종특별자치시      3
# 울산광역시       17
# 인천광역시       42
# 전라남도        14
# 전라북도        16
# 제주특별자치도      7
# 충청남도        22
# 충청북도        15
# Name: 실업자 (천명), dtype: int64

# %%
sido_sum.index
# Out:
# Index(['강원도', '경기도', '경상남도', '경상북도', '광주광역시', '대구광역시', '대전광역시', '부산광역시',
#        '서울특별시', '세종특별자치시', '울산광역시', '인천광역시', '전라남도', '전라북도', '제주특별자치도', '충청남도',
#        '충청북도'],
#       dtype='object', name='행정구역(시도)')

# %%
plt.pie(unemp_sum.values, labels = unemp_sum.index , autopct = '%.1f%%')
#legend 위치 이동시키기
plt.legend(bbox_to_anchor=(1.3, 1.0), loc="upper left")

#matplotlib 스타일 설정
plt.style.use('ggplot')
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50896 (\N{HANGUL SYLLABLE WEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# ...
